# %% [markdown]
# # Model Experiments

# %%
import sys
import os
# %load_ext autoreload
# %autoreload 2

sys.path.append(os.path.abspath("../src"))

# %% [markdown]
# ## Spark + Data Initialisation

# %%
# Column titles
USER_COL = 'userId'
ITEM_COL = 'movieId'
RATING_COL = 'rating'
TIMESTAMP_COL = 'timestamp'

# %%
from utils.spark_session import get_spark
from pyspark.sql.types import StructType, StructField, IntegerType, TimestampType, FloatType

spark = get_spark()

# schema structure
ratings_schema = StructType([
    StructField(USER_COL, IntegerType(), True),
    StructField(ITEM_COL, IntegerType(), True),
    StructField(RATING_COL, FloatType(), True),
    StructField(TIMESTAMP_COL, TimestampType(), True)
])

# load csv as dataframe
ratings = spark.read.csv("../data/raw/rating.csv", schema=ratings_schema, header=True)
ratings.printSchema()
ratings.show(5)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/03/04 13:10:00 WARN Utils: Your hostname, Davids-MacBook-Pro.local, resolves to a loopback address: 127.0.0.1; using 192.168.1.103 instead (on interface en0)
# 26/03/04 13:10:00 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/04 13:10:02 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# root
#  |-- userId: integer (nullable = true)
#  |-- movieId: integer (nullable = true)
#  |-- rating: float (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
# [Stage 0:>                                                          (0 + 1) / 1]
# +------+-------+------+-------------------+
# |userId|movieId|rating|          timestamp|
# +------+-------+------+-------------------+
# |     1|      2|   3.5|2005-04-02 23:53:47|
# |     1|     29|   3.5|2005-04-02 23:31:16|
# |     1|     32|   3.5|2005-04-02 23:33:39|
# |     1|     47|   3.5|2005-04-02 23:32:07|
# |     1|     50|   3.5|2005-04-02 23:29:40|
# +------+-------+------+-------------------+
# only showing top 5 rows

# %% [markdown]
# ## Data Split
# To minimise data leakage, training data will be split chronologically so that future user preferences aren't erroneously used to train predictions.
#
# To avoid cold-start problems, each user will be represented in both the training and test dataset. Having a high min. number of ratings per user of 20 allows this.

# %%
# Split data + cache training data for performance
from data.split_data import chron_user_tt_split

train, test = chron_user_tt_split(ratings, USER_COL, TIMESTAMP_COL, 0.8)
train.cache()
train.count()
# Out:
# 16043134

# %% [markdown]
# ## Retrieval: ALS
# Computing ALS to reduce model items from millions to hundreds for ranking

# %%
from pyspark.ml.recommendation import ALS

als = ALS( maxIter=15, rank=15, implicitPrefs=False,
          regParam=0.05, coldStartStrategy='drop',
          nonnegative=False, seed=2026,
          userCol=USER_COL, itemCol=ITEM_COL,
          ratingCol=RATING_COL
)

# %%
model = als.fit(train)
# Out:
# 26/03/04 13:12:10 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# 26/03/04 13:12:12 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.lapack.JNILAPACK

# %%
TOP_K = 500
recs = model.recommendForAllUsers(TOP_K)

# %% [markdown]
# ### Seen Film Removal
# Although ALS' recommendForAllUsers removes already seen films from the recommendations dataframe, some seen films do remain.

# %%
## Smaller random sample  for debugging duplicate function + caching for fast use

small_df = recs.sample(fraction=0.001, seed=206)
small_df.cache()
small_df.count()
# Out:
# 26/03/04 15:18:41 WARN CacheManager: Asked to cache already cached data.
# 136

# %%
# Filtering recommendations
from retrieval.post_processing import remove_duplicates
recs_no_dup = remove_duplicates(recs, train)
