# %% [markdown]
# # Model Experiments

# %%
import sys
import os
# %load_ext autoreload
# %autoreload 2

sys.path.append(os.path.abspath("../src"))

# %% [markdown]
# ## Spark + Data Initialisation

# %%
# Column titles
USER_COL = 'userId'
ITEM_COL = 'movieId'
RATING_COL = 'rating'
TIMESTAMP_COL = 'timestamp'

# %%
from utils.spark_session import get_spark
from pyspark.sql.types import StructType, StructField, IntegerType, TimestampType, FloatType

spark = get_spark()
spark.sparkContext.setLogLevel("INFO")

# schema structure
ratings_schema = StructType([
    StructField(USER_COL, IntegerType(), True),
    StructField(ITEM_COL, IntegerType(), True),
    StructField(RATING_COL, FloatType(), True),
    StructField(TIMESTAMP_COL, TimestampType(), True)
])

# load csv as dataframe
ratings = spark.read.csv("../data/raw/rating.csv", schema=ratings_schema, header=True)
ratings.printSchema()
ratings.show(5)
# Out:
# root
#  |-- userId: integer (nullable = true)
#  |-- movieId: integer (nullable = true)
#  |-- rating: float (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#
# +------+-------+------+-------------------+
# |userId|movieId|rating|          timestamp|
# +------+-------+------+-------------------+
# |     1|      2|   3.5|2005-04-02 23:53:47|
# |     1|     29|   3.5|2005-04-02 23:31:16|
# |     1|     32|   3.5|2005-04-02 23:33:39|
# |     1|     47|   3.5|2005-04-02 23:32:07|
# |     1|     50|   3.5|2005-04-02 23:29:40|
# +------+-------+------+-------------------+
# only showing top 5 rows

# %% [markdown]
# ## Data Split
# To minimise data leakage, training data will be split chronologically so that future user preferences aren't erroneously used to train predictions.
#
# Each user will be represented in both the training and test dataset. This allows evaluation on test data to compare to retrieval and ranking lists.
#
# NB: The high min. number of ratings per user of 20 allows this and avoids cold-start issues.

# %%
# Split data + cache training data for performance
from data.split_data import chron_user_tt_split

train, test = chron_user_tt_split(ratings, USER_COL, TIMESTAMP_COL, 0.8)
train.cache()
train.count()
# Out:
# 16043134

# %% [markdown]
# ## Retrieval: ALS
# Computing ALS to reduce model items from millions to hundreds for ranking

# %%
from pyspark.ml.recommendation import ALS

als = ALS(alpha=20, maxIter=15, rank=50, implicitPrefs=True,
          regParam=0.05, coldStartStrategy='drop',
          nonnegative=False, seed=2026,
          userCol=USER_COL, itemCol=ITEM_COL,
          ratingCol=RATING_COL
)

# %%
model = als.fit(train)

# %%
TOP_K = 100
recs = model.recommendForAllUsers(TOP_K)

# %% [markdown]
# ### Seen Film Removal
# Although ALS' recommendForAllUsers removes already seen films from the recommendations dataframe, some seen films do remain.

# %%
## Smaller random sample  for debugging duplicate function + caching for fast use

small_df = recs.sample(fraction=0.001, seed=206)
small_df.cache()
small_df.count()
# Out:
# 136

# %%
# Filtering recommendations
from retrieval.post_processing import remove_duplicates
recs_filtered = remove_duplicates(recs, train) # CHANGE: small_df --> recs for prod

# %% [markdown]
# ### Evaluation

# %%
## Smaller random sample  for debugging duplicate function + caching for fast use

small_test = test.sample(fraction=0.05, seed=206)
small_test.cache()
small_test.count()
# Out:
# 198104

# %%
# Filter test results to only show test items of rating 4+
test_filtered = test.filter(test.rating >= 4)

# %%
from pyspark.mllib.evaluation import RankingMetrics as RM
from pyspark.sql import functions as F

## Creating df in form of:
# userId (int), pred_items [movieId,], true_items [moveId,]

# Group matrix predictions per user
pred_grouped = recs_filtered.groupBy('userId').agg(
    F.collect_list('movieId').alias('pred_items')
)

true_grouped = test_filtered.groupBy('userId').agg( # CHANGE: small_test --> test for prod
    F.collect_list('movieId').alias('true_items')
)

# Join to create eval df
eval_df = pred_grouped.join(true_grouped, on='userId')

# %%
rdd = eval_df.select(
    "pred_items", "true_items"
).rdd.map(
    lambda row: (row.pred_items, row.true_items)
)

# %%
metrics = RM(rdd)

# %%
eval_K = 100
print(f"Precision@{eval_K}:", metrics.precisionAt(eval_K))
print(f"Recall@{eval_K}:", metrics.recallAt(eval_K))
print(f"NDCG@{eval_K}:", metrics.ndcgAt(eval_K))
print("MAP:", metrics.meanAveragePrecision)
# Out:
# Precision@100: 0.0016477043069507015
# Recall@100: 0.01912040818211054
# NDCG@100: 0.006294957456994094
# MAP: 0.0004773416749881822

# %%
eval_K = 100
print(f"Precision@{eval_K}:", metrics.precisionAt(eval_K))
print(f"Recall@{eval_K}:", metrics.recallAt(eval_K))
print(f"NDCG@{eval_K}:", metrics.ndcgAt(eval_K))
print("MAP:", metrics.meanAveragePrecision)
# Out:
# Precision@100: 0.02305609617342358
# Recall@100: 0.30188918547315663
# NDCG@100: 0.1408968740805938
# MAP: 0.04145013338520301
